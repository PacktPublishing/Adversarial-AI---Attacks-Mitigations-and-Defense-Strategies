# %%
import warnings
warnings.filterwarnings('ignore')

import random
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 10]

import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

from art.estimators.classification import TensorFlowV2Classifier, EnsembleClassifier
from art.attacks.evasion import AdversarialPatch
import sys
sys.path.append('../lib')
import utils
from utils import load_preprocess, show_adversarial_images
# Out:
# 2024-06-10 15:18:52.045369: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 15:18:52.045403: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 15:18:52.046463: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
image_shape = (224, 224, 3)
clip_values = (0, 255)
batch_size = 16
scale_min = 0.4
scale_max = 1.0
rotation_max = 22.5
learning_rate = 5000.
max_iter = 500

# %%
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
model = ResNet50V2(weights="imagenet")

mean_b = 103.939
mean_g = 116.779
mean_r = 123.680

tfc = TensorFlowV2Classifier(model=model, loss_object=None, train_step=None, 
                             input_shape=image_shape, clip_values=clip_values, nb_classes=1000,
                             preprocessing=([mean_b, mean_g, mean_r], np.array([1.0, 1.0, 1.0])))

# %%
ap = AdversarialPatch(classifier=tfc, rotation_max=rotation_max, scale_min=scale_min, scale_max=scale_max,
                      learning_rate=learning_rate, max_iter=max_iter, batch_size=batch_size,
                      patch_shape=(224, 224, 3))

target_class = 281  # 'tabby cat' class in ImageNet
y_one_hot = np.zeros(1000)
y_one_hot[target_class] = 1.0

y_target = np.expand_dims(y_one_hot, axis=0)  # Shape (1, 1000)
img = load_preprocess('../images/racing-car.jpg')

patch, patch_mask = ap.generate(x=img, y=y_target)
# Out:
# Adversarial Patch TensorFlow v2:   0%|          | 0/500 [00:00<?, ?it/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718029138.597314  195327 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
patched_image = ap.apply_patch(img, scale=0.5)

# %%
utils.show_image(img[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Classify the original and patched images
def classify_image(img):
    preds = model.predict(img)
    return decode_predictions(preds, top=3)[0]

# Classify and display the results
original_preds = classify_image(img)
patched_preds = classify_image(patched_image)

print("Original Image Predictions:")
for pred in original_preds:
    print(f"{pred[1]}: {pred[2]*100:.2f}%")

print("\nPatched Image Predictions:")
for pred in patched_preds:
    print(f"{pred[1]}: {pred[2]*100:.2f}%")
# Out:
# 1/1 [==============================] - 1s 508ms/step
# 1/1 [==============================] - 0s 14ms/step
# Original Image Predictions:
# racer: 64.21%
# sports_car: 23.06%
# grille: 4.53%
#
# Patched Image Predictions:
# Siamese_cat: 98.49%
# fox_squirrel: 1.50%
# bulbul: 0.01%
