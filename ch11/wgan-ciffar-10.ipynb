# %%
# example of a wcgan on cifar10
import numpy as np
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam, RMSprop
import tensorflow.keras.backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot
from datetime import datetime
import os

# %%
# load and preprocess cifar10 images
def load_real_samples():
    # load cifar10 dataset
    (trainX, _), (_, _) = load_data()
    # convert from unsigned ints to floats
    X = trainX.astype('float32')
    # scale from [0,255] to [-1,1] 
    X = (X - 127.5) / 127.5
    return X
# select real samples
def generate_real_samples(dataset, n_samples):
    # choose random instances
    ix = randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[ix]
    # generate 'real' class labels (1)
    #y = ones((n_samples, 1))
    # generate 'real' class labels (-11)
    y = -ones((n_samples, 1))

    return X,y

# %%
def wasserstein_loss(y_true, y_pred):
    return K.mean(y_true * y_pred)

# %%
# Generator
def build_generator(latent_dim):
	model = Sequential()
	n_nodes = 256 * 4 * 4
	model.add(Dense(n_nodes, input_dim=latent_dim))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Reshape((4, 4, 256)))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
	return model

#Discriminator model

def build_discriminator(in_shape=(32,32,3)):
    model = Sequential()
    # Normal
    model.add(Conv2D(64, (3,3), padding='same', input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(64, (3,3), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(128, (3,3), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Flatten())
    model.add(Dense(1))
    #Adjust the optimizer to RMSProp with a lower learning rate
    opt = RMSprop(learning_rate=0.00005)
    # Compile the discriminator model
    model.compile(loss=wasserstein_loss, optimizer=opt)
    return model

discriminator = build_discriminator()

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    x_input = randn(latent_dim * n_samples)
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
    x_input = generate_latent_points(latent_dim, n_samples)
    X = g_model.predict(x_input)
    # create 'fake' class labels (1)
    y = np.ones((n_samples, 1))
    return X, y

# show the generated images
def show_generated_images(images, n_samples):
    # scale pixel values from [-1,1] to [0,1]
    images = (images + 1) / 2.0
    # plot the generated samples
    for i in range(n_samples):
        # define subplot
        pyplot.subplot(7, 7, 1 + i)
        # turn off axis labels
        pyplot.axis('off')
        # plot single image
        pyplot.imshow(images[i])
    # show the figure
    pyplot.show()

# %%
def build_gan(generator, discriminator):
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))
    return model

# %%
# create a time-stamped folder name for results to avoid overwriting them
def create_results_path(base_path):
    # Get the current date and time
    now = datetime.now()
    # Format the date and time in the specified format
    date_time_suffix = now.strftime("%Y-%m-%d-%H-%M")
    # Combine the base path with the date and time suffix
    results_path = os.path.join(base_path, f"results_{date_time_suffix}")
    # Create the directory if it doesn't exist
    if not os.path.exists(results_path):
        os.makedirs(results_path)
    return results_path    
    return X

def save_plot(examples, epoch, n=7, results_path='.'):
    examples = (examples + 1) / 2.0
    for i in range(n * n):
        pyplot.subplot(n, n, 1 + i)
        pyplot.axis('off')
        pyplot.imshow(examples[i])
    filename = os.path.join(results_path, 'generated_plot_e%03d.png' % (epoch+1))
    pyplot.savefig(filename)
    pyplot.close()

def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=150, results_path='.'):
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
    x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
    y_real = ones((n_samples, 1))
    y_fake = zeros((n_samples, 1))
    _, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
    print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
    save_plot(x_fake, epoch)
    filename = 'generator_model_%03d.h5' % (epoch+1)
    filename = os.path.join(results_path, filename)
    g_model.save(filename)

def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=150, results_path='.'):
    X_real, y_real = generate_real_samples(dataset, n_samples)
    loss_real, acc_real = d_model.evaluate(X_real, y_real, verbose=0)  # Changed line
    x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
    loss_fake, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)  # Changed line
    print('Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
    save_plot(x_fake, epoch, results_path=results_path)
    filename = '%s/model_%03d.h5' % (results_path, (epoch+1))
    g_model.save(filename)


def train_generator(gan, latent_dim, n_batch):
    X_gan = generate_latent_points(latent_dim, n_batch)
    y_gan = ones((n_batch, 1))
    g_loss = gan.train_on_batch(X_gan, y_gan)
    return g_loss

def clip_discriminator_weights(discriminator, clip_value=0.01):
    for l in discriminator.layers:
        weights = l.get_weights()
        weights = [np.clip(w, -clip_value, clip_value) for w in weights]
        l.set_weights(weights)


def train_gan(generator, discriminator, gan_model, dataset, latent_dim, n_epochs=200, batch_size=128, results_path='.'):
    batch_per_epoch = int(dataset.shape[0] / batch_size)
    for i in range(n_epochs):
        for j in range(batch_per_epoch):
            # Train the discriminator and get the losses
            d_loss1, d_loss2 = train_discriminator(discriminator, generator, dataset, latent_dim, batch_size)
            # Clip discriminator weights
            clip_discriminator_weights(discriminator)
            # Train the generator
            g_loss = train_generator(gan_model, latent_dim, batch_size)
            # Update batch progress
            print('>%d, %d/%d, d1=%.3f, d2=%.3f, g=%.3f' % (i+1, j+1, batch_per_epoch, d_loss1, d_loss2, g_loss))
            if d_loss1 < 0.05 or d_loss1 > 0.8:  
                print(f"Warning: Discriminator loss for fake data out of bounds at epoch {i+1}, batch {j+1}")
            if d_loss2 < 0.05 or d_loss2 > 0.8:  
                print(f"Warning: Discriminator loss for real data out of bounds at epoch {i+1}, batch {j+1}")
        update_step = n_epochs // 10  
        if (i+1) % update_step == 0:
            summarize_performance(i, generator, discriminator, dataset, latent_dim, results_path=results_path)

# %%
from numpy import zeros
from numpy import ones
dataset = load_real_samples()
latent_dim = 100
generator = build_generator(latent_dim)
discriminator = build_discriminator()
gan = build_gan(generator, discriminator)
results_path = create_results_path('.')
train_gan(generator, discriminator, gan, dataset, latent_dim, results_path=results_path)
# Out:
# WARNING:tensorflow:6 out of the last 1175 calls to <function Model.make_train_function.<locals>.train_function at 0x7f663c123be0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 2ms/step
# >1, 1/390, d1=-0.013, d2=0.005, g=8.321
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 1
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 1
# 2/2 [==============================] - 0s 1ms/step
# >1, 2/390, d1=-0.000, d2=0.001, g=8.309
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 2
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 2
# 2/2 [==============================] - 0s 1ms/step
# >1, 3/390, d1=-0.000, d2=0.001, g=8.379
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 3
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 3
# 2/2 [==============================] - 0s 1ms/step
# >1, 4/390, d1=-0.000, d2=0.001, g=8.398
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 4
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 4
# 2/2 [==============================] - 0s 1ms/step
# >1, 5/390, d1=-0.000, d2=0.000, g=8.358
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 5
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 5
# 2/2 [==============================] - 0s 1ms/step
# >1, 6/390, d1=-0.000, d2=0.000, g=8.322
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 6
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 6
# 2/2 [==============================] - 0s 1ms/step
# >1, 7/390, d1=-0.000, d2=0.001, g=8.212
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 7
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 7
# 2/2 [==============================] - 0s 1ms/step
# >1, 8/390, d1=-0.000, d2=0.001, g=8.071
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 8
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 8
# 2/2 [==============================] - 0s 1ms/step
# >1, 9/390, d1=-0.000, d2=0.001, g=7.949
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 9
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 9
# 2/2 [==============================] - 0s 2ms/step
# >1, 10/390, d1=-0.000, d2=0.001, g=7.833
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 10
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 10
# 2/2 [==============================] - 0s 1ms/step
# >1, 11/390, d1=-0.000, d2=0.001, g=7.748
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 11
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 11
# 2/2 [==============================] - 0s 1ms/step
# >1, 12/390, d1=-0.000, d2=0.001, g=7.693
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 12
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 12
# 2/2 [==============================] - 0s 1ms/step
# >1, 13/390, d1=-0.000, d2=0.001, g=7.720
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 13
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 13
# 2/2 [==============================] - 0s 1ms/step
# >1, 14/390, d1=-0.000, d2=0.001, g=7.820
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 14
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 14
# 2/2 [==============================] - 0s 2ms/step
# >1, 15/390, d1=-0.000, d2=0.001, g=7.983
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 15
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 15
# 2/2 [==============================] - 0s 2ms/step
# >1, 16/390, d1=-0.000, d2=0.001, g=8.114
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 16
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 16
# 2/2 [==============================] - 0s 1ms/step
# >1, 17/390, d1=-0.000, d2=0.001, g=8.247
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 17
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 17
# 2/2 [==============================] - 0s 1ms/step
# >1, 18/390, d1=-0.000, d2=0.001, g=8.335
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 18
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 18
# 2/2 [==============================] - 0s 2ms/step
# >1, 19/390, d1=-0.000, d2=0.001, g=8.347
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 19
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 19
# 2/2 [==============================] - 0s 1ms/step
# >1, 20/390, d1=-0.000, d2=0.001, g=8.351
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 20
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 20
# 2/2 [==============================] - 0s 1ms/step
# >1, 21/390, d1=-0.000, d2=0.001, g=8.370
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 21
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 21
# 2/2 [==============================] - 0s 1ms/step
# >1, 22/390, d1=-0.000, d2=0.001, g=8.348
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 22
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 22
# 2/2 [==============================] - 0s 1ms/step
# >1, 23/390, d1=-0.000, d2=0.001, g=8.414
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 23
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 23
# 2/2 [==============================] - 0s 1ms/step
# >1, 24/390, d1=-0.000, d2=0.001, g=8.492
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 24
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 24
# 2/2 [==============================] - 0s 1ms/step
# >1, 25/390, d1=-0.000, d2=0.001, g=8.495
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 25
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 25
# 2/2 [==============================] - 0s 1ms/step
# >1, 26/390, d1=-0.000, d2=0.000, g=8.560
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 26
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 26
# 2/2 [==============================] - 0s 1ms/step
# >1, 27/390, d1=-0.000, d2=0.001, g=8.483
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 27
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 27
# 2/2 [==============================] - 0s 1ms/step
# >1, 28/390, d1=-0.000, d2=0.001, g=8.358
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 28
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 28
# 2/2 [==============================] - 0s 1ms/step
# >1, 29/390, d1=-0.000, d2=0.001, g=8.327
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 29
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 29
# 2/2 [==============================] - 0s 1ms/step
# >1, 30/390, d1=-0.000, d2=0.001, g=8.480
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 30
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 30
# 2/2 [==============================] - 0s 1ms/step
# >1, 31/390, d1=-0.000, d2=0.001, g=8.576
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 31
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 31
# 2/2 [==============================] - 0s 1ms/step
# >1, 32/390, d1=-0.000, d2=0.000, g=8.680
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 32
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 32
# 2/2 [==============================] - 0s 1ms/step
# >1, 33/390, d1=-0.000, d2=0.000, g=8.797
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 33
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 33
# 2/2 [==============================] - 0s 1ms/step
# >1, 34/390, d1=-0.000, d2=0.000, g=8.919
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 34
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 34
# 2/2 [==============================] - 0s 1ms/step
# >1, 35/390, d1=-0.000, d2=0.000, g=9.084
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 35
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 35
# 2/2 [==============================] - 0s 1ms/step
# >1, 36/390, d1=-0.000, d2=0.000, g=9.232
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 36
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 36
# 2/2 [==============================] - 0s 1ms/step
# >1, 37/390, d1=-0.000, d2=0.000, g=9.267
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 37
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 37
# 2/2 [==============================] - 0s 1ms/step
# >1, 38/390, d1=-0.000, d2=0.000, g=9.338
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 38
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 38
# 2/2 [==============================] - 0s 1ms/step
# >1, 39/390, d1=-0.000, d2=0.000, g=9.267
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 39
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 39
# 2/2 [==============================] - 0s 1ms/step
# >1, 40/390, d1=-0.000, d2=0.000, g=9.249
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 40
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 40
# 2/2 [==============================] - 0s 2ms/step
# >1, 41/390, d1=-0.000, d2=0.000, g=9.238
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 41
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 41
# 2/2 [==============================] - 0s 1ms/step
# >1, 42/390, d1=-0.000, d2=0.000, g=9.229
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 42
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 42
# 2/2 [==============================] - 0s 1ms/step
# >1, 43/390, d1=-0.000, d2=0.000, g=9.250
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 43
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 43
# 2/2 [==============================] - 0s 1ms/step
# >1, 44/390, d1=-0.000, d2=0.000, g=9.301
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 44
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 44
# 2/2 [==============================] - 0s 1ms/step
# >1, 45/390, d1=-0.000, d2=0.000, g=9.237
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 45
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 45
# 2/2 [==============================] - 0s 1ms/step
# >1, 46/390, d1=-0.000, d2=0.000, g=9.035
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 46
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 46
# 2/2 [==============================] - 0s 1ms/step
# >1, 47/390, d1=-0.000, d2=0.000, g=9.048
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 47
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 47
# 2/2 [==============================] - 0s 1ms/step
# >1, 48/390, d1=-0.000, d2=0.000, g=9.129
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 48
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 48
# 2/2 [==============================] - 0s 1ms/step
# >1, 49/390, d1=-0.000, d2=0.000, g=9.185
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 49
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 49
# 2/2 [==============================] - 0s 1ms/step
# >1, 50/390, d1=-0.000, d2=0.000, g=9.534
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 50
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 50
# 2/2 [==============================] - 0s 1ms/step
# >1, 51/390, d1=-0.000, d2=0.000, g=9.783
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 51
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 51
# 2/2 [==============================] - 0s 2ms/step
# >1, 52/390, d1=-0.000, d2=0.000, g=9.684
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 52
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 52
# 2/2 [==============================] - 0s 1ms/step
# >1, 53/390, d1=-0.000, d2=0.000, g=9.179
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 53
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 53
# 2/2 [==============================] - 0s 1ms/step
# >1, 54/390, d1=-0.000, d2=0.000, g=9.226
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 54
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 54
# 2/2 [==============================] - 0s 1ms/step
# >1, 55/390, d1=-0.000, d2=0.000, g=9.243
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 55
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 55
# 2/2 [==============================] - 0s 1ms/step
# >1, 56/390, d1=-0.000, d2=0.000, g=8.971
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 56
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 56
# 2/2 [==============================] - 0s 1ms/step
# >1, 57/390, d1=-0.000, d2=0.001, g=8.644
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 57
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 57
# 2/2 [==============================] - 0s 2ms/step
# >1, 58/390, d1=-0.000, d2=0.001, g=8.555
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 58
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 58
# 2/2 [==============================] - 0s 1ms/step
# >1, 59/390, d1=-0.000, d2=0.001, g=8.394
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 59
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 59
# 2/2 [==============================] - 0s 2ms/step
# >1, 60/390, d1=-0.000, d2=0.001, g=8.364
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 60
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 60
# 2/2 [==============================] - 0s 1ms/step
# >1, 61/390, d1=-0.000, d2=0.001, g=8.401
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 61
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 61
# 2/2 [==============================] - 0s 1ms/step
# >1, 62/390, d1=-0.000, d2=0.001, g=8.333
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 62
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 62
# 2/2 [==============================] - 0s 1ms/step
# >1, 63/390, d1=-0.000, d2=0.001, g=8.327
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 63
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 63
# 2/2 [==============================] - 0s 1ms/step
# >1, 64/390, d1=-0.000, d2=0.001, g=8.357
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 64
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 64
# 2/2 [==============================] - 0s 2ms/step
# >1, 65/390, d1=-0.000, d2=0.001, g=8.442
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 65
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 65
# 2/2 [==============================] - 0s 1ms/step
# >1, 66/390, d1=-0.000, d2=0.001, g=8.531
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 66
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 66
# 2/2 [==============================] - 0s 1ms/step
# >1, 67/390, d1=-0.000, d2=0.001, g=8.625
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 67
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 67
# 2/2 [==============================] - 0s 1ms/step
# >1, 68/390, d1=-0.000, d2=0.001, g=8.696
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 68
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 68
# 2/2 [==============================] - 0s 1ms/step
# >1, 69/390, d1=-0.000, d2=0.000, g=8.761
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 69
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 69
# 2/2 [==============================] - 0s 1ms/step
# >1, 70/390, d1=-0.000, d2=0.001, g=8.774
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 70
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 70
# 2/2 [==============================] - 0s 2ms/step
# >1, 71/390, d1=-0.000, d2=0.001, g=8.733
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 71
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 71
# 2/2 [==============================] - 0s 2ms/step
# >1, 72/390, d1=-0.000, d2=0.000, g=9.106
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 72
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 72
# 2/2 [==============================] - 0s 2ms/step
# >1, 73/390, d1=-0.000, d2=0.000, g=9.340
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 73
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 73
# 2/2 [==============================] - 0s 1ms/step
# >1, 74/390, d1=-0.000, d2=0.001, g=8.835
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 74
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 74
# 2/2 [==============================] - 0s 2ms/step
# >1, 75/390, d1=-0.000, d2=0.000, g=9.091
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 75
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 75
# 2/2 [==============================] - 0s 1ms/step
# >1, 76/390, d1=-0.000, d2=0.000, g=9.385
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 76
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 76
# 2/2 [==============================] - 0s 1ms/step
# >1, 77/390, d1=-0.000, d2=0.000, g=9.539
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 77
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 77
# 2/2 [==============================] - 0s 1ms/step
# >1, 78/390, d1=-0.000, d2=0.000, g=9.799
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 78
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 78
# 2/2 [==============================] - 0s 1ms/step
# >1, 79/390, d1=-0.000, d2=0.000, g=9.612
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 79
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 79
# 2/2 [==============================] - 0s 1ms/step
# >1, 80/390, d1=-0.000, d2=0.000, g=9.870
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 80
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 80
# 2/2 [==============================] - 0s 1ms/step
# >1, 81/390, d1=-0.000, d2=0.000, g=10.384
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 81
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 81
# 2/2 [==============================] - 0s 1ms/step
# >1, 82/390, d1=-0.001, d2=0.000, g=9.981
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 82
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 82
# 2/2 [==============================] - 0s 2ms/step
# >1, 83/390, d1=-0.001, d2=0.000, g=9.975
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 83
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 83
# 2/2 [==============================] - 0s 1ms/step
# >1, 84/390, d1=-0.001, d2=0.001, g=9.110
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 84
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 84
# 2/2 [==============================] - 0s 1ms/step
# >1, 85/390, d1=-0.001, d2=0.001, g=9.039
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 85
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 85
# 2/2 [==============================] - 0s 1ms/step
# >1, 86/390, d1=-0.001, d2=0.001, g=8.884
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 86
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 86
# 2/2 [==============================] - 0s 1ms/step
# >1, 87/390, d1=-0.001, d2=0.001, g=8.796
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 87
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 87
# 2/2 [==============================] - 0s 1ms/step
# >1, 88/390, d1=-0.001, d2=0.001, g=9.148
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 88
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 88
# 2/2 [==============================] - 0s 2ms/step
# >1, 89/390, d1=-0.000, d2=0.000, g=9.428
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 89
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 89
# 2/2 [==============================] - 0s 1ms/step
# >1, 90/390, d1=-0.001, d2=0.000, g=9.494
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 90
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 90
# 2/2 [==============================] - 0s 1ms/step
# >1, 91/390, d1=-0.001, d2=0.001, g=9.293
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 91
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 91
# 2/2 [==============================] - 0s 1ms/step
# >1, 92/390, d1=-0.000, d2=0.001, g=8.979
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 92
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 92
# 2/2 [==============================] - 0s 2ms/step
# >1, 93/390, d1=-0.001, d2=0.001, g=8.946
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 93
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 93
# 2/2 [==============================] - 0s 1ms/step
# >1, 94/390, d1=-0.001, d2=0.001, g=8.997
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 94
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 94
# 2/2 [==============================] - 0s 1ms/step
# >1, 95/390, d1=-0.001, d2=0.001, g=8.923
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 95
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 95
# 2/2 [==============================] - 0s 2ms/step
# >1, 96/390, d1=-0.001, d2=0.001, g=8.719
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 96
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 96
# 2/2 [==============================] - 0s 1ms/step
# >1, 97/390, d1=-0.001, d2=0.001, g=8.387
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 97
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 97
# 2/2 [==============================] - 0s 2ms/step
# >1, 98/390, d1=-0.001, d2=0.001, g=8.163
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 98
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 98
# 2/2 [==============================] - 0s 1ms/step
# >1, 99/390, d1=-0.001, d2=0.001, g=8.103
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 99
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 99
# 2/2 [==============================] - 0s 1ms/step
# >1, 100/390, d1=-0.001, d2=0.001, g=8.076
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 100
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 100
# 2/2 [==============================] - 0s 1ms/step
# >1, 101/390, d1=-0.001, d2=0.001, g=8.120
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 101
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 101
# 2/2 [==============================] - 0s 1ms/step
# >1, 102/390, d1=-0.001, d2=0.001, g=8.112
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 102
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 102
# 2/2 [==============================] - 0s 1ms/step
# >1, 103/390, d1=-0.001, d2=0.001, g=8.034
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 103
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 103
# 2/2 [==============================] - 0s 1ms/step
# >1, 104/390, d1=-0.001, d2=0.001, g=7.981
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 104
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 104
# 2/2 [==============================] - 0s 2ms/step
# >1, 105/390, d1=-0.001, d2=0.001, g=8.016
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 105
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 105
# 2/2 [==============================] - 0s 1ms/step
# >1, 106/390, d1=-0.001, d2=0.001, g=8.091
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 106
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 106
# 2/2 [==============================] - 0s 1ms/step
# >1, 107/390, d1=-0.001, d2=0.001, g=8.175
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 107
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 107
# 2/2 [==============================] - 0s 1ms/step
# >1, 108/390, d1=-0.001, d2=0.001, g=8.295
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 108
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 108
# 2/2 [==============================] - 0s 1ms/step
# >1, 109/390, d1=-0.001, d2=0.001, g=8.477
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 109
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 109
# 2/2 [==============================] - 0s 1ms/step
# >1, 110/390, d1=-0.001, d2=0.001, g=8.723
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 110
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 110
# 2/2 [==============================] - 0s 1ms/step
# >1, 111/390, d1=-0.001, d2=0.001, g=9.017
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 111
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 111
# 2/2 [==============================] - 0s 1ms/step
# >1, 112/390, d1=-0.001, d2=0.000, g=9.302
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 112
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 112
# 2/2 [==============================] - 0s 2ms/step
# >1, 113/390, d1=-0.001, d2=0.000, g=9.300
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 113
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 113
# 2/2 [==============================] - 0s 1ms/step
# >1, 114/390, d1=-0.001, d2=0.001, g=9.092
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 114
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 114
# 2/2 [==============================] - 0s 2ms/step
# >1, 115/390, d1=-0.001, d2=0.001, g=8.855
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 115
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 115
# 2/2 [==============================] - 0s 1ms/step
# >1, 116/390, d1=-0.001, d2=0.001, g=8.814
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 116
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 116
# 2/2 [==============================] - 0s 1ms/step
# >1, 117/390, d1=-0.001, d2=0.001, g=9.076
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 117
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 117
# 2/2 [==============================] - 0s 1ms/step
# >1, 118/390, d1=-0.001, d2=0.000, g=9.348
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 118
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 118
# 2/2 [==============================] - 0s 1ms/step
# >1, 119/390, d1=-0.001, d2=0.000, g=9.587
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 119
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 119
# 2/2 [==============================] - 0s 1ms/step
# >1, 120/390, d1=-0.001, d2=0.000, g=9.610
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 120
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 120
# 2/2 [==============================] - 0s 1ms/step
# >1, 121/390, d1=-0.001, d2=0.000, g=9.353
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 121
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 121
# 2/2 [==============================] - 0s 1ms/step
# >1, 122/390, d1=-0.001, d2=0.000, g=9.809
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 122
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 122
# 2/2 [==============================] - 0s 2ms/step
# >1, 123/390, d1=-0.001, d2=0.000, g=12.857
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 123
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 123
# 2/2 [==============================] - 0s 1ms/step
# >1, 124/390, d1=-0.001, d2=0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 124
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 124
# 2/2 [==============================] - 0s 1ms/step
# >1, 125/390, d1=-0.001, d2=0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 125
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 125
# 2/2 [==============================] - 0s 1ms/step
# >1, 126/390, d1=-0.001, d2=0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 126
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 126
# 2/2 [==============================] - 0s 1ms/step
# >1, 127/390, d1=-0.001, d2=-0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 127
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 127
# 2/2 [==============================] - 0s 1ms/step
# >1, 128/390, d1=-0.001, d2=-0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 128
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 128
# 2/2 [==============================] - 0s 1ms/step
# >1, 129/390, d1=-0.001, d2=-0.000, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 129
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 129
# 2/2 [==============================] - 0s 2ms/step
# >1, 130/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 130
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 130
# 2/2 [==============================] - 0s 1ms/step
# >1, 131/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 131
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 131
# 2/2 [==============================] - 0s 1ms/step
# >1, 132/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 132
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 132
# 2/2 [==============================] - 0s 1ms/step
# >1, 133/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 133
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 133
# 2/2 [==============================] - 0s 2ms/step
# >1, 134/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 134
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 134
# 2/2 [==============================] - 0s 2ms/step
# >1, 135/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 135
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 135
# 2/2 [==============================] - 0s 1ms/step
# >1, 136/390, d1=-0.001, d2=-0.001, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 136
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 136
# 2/2 [==============================] - 0s 2ms/step
# >1, 137/390, d1=-0.001, d2=-0.002, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 137
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 137
# 2/2 [==============================] - 0s 1ms/step
# >1, 138/390, d1=-0.001, d2=-0.002, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 138
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 138
# 2/2 [==============================] - 0s 2ms/step
# >1, 139/390, d1=-0.001, d2=-0.002, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 139
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 139
# 2/2 [==============================] - 0s 1ms/step
# >1, 140/390, d1=-0.001, d2=-0.002, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 140
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 140
# 2/2 [==============================] - 0s 1ms/step
# >1, 141/390, d1=-0.001, d2=-0.002, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 141
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 141
# 2/2 [==============================] - 0s 1ms/step
# >1, 142/390, d1=-0.001, d2=-0.003, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 142
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 142
# 2/2 [==============================] - 0s 1ms/step
# >1, 143/390, d1=-0.001, d2=-0.003, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 143
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 143
# 2/2 [==============================] - 0s 2ms/step
# >1, 144/390, d1=-0.002, d2=-0.003, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 144
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 144
# 2/2 [==============================] - 0s 1ms/step
# >1, 145/390, d1=-0.002, d2=-0.004, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 145
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 145
# 2/2 [==============================] - 0s 2ms/step
# >1, 146/390, d1=-0.002, d2=-0.004, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 146
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 146
# 2/2 [==============================] - 0s 1ms/step
# >1, 147/390, d1=-0.002, d2=-0.004, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 147
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 147
# 2/2 [==============================] - 0s 1ms/step
# >1, 148/390, d1=-0.002, d2=-0.005, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 148
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 148
# 2/2 [==============================] - 0s 1ms/step
# >1, 149/390, d1=-0.002, d2=-0.005, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 149
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 149
# 2/2 [==============================] - 0s 1ms/step
# >1, 150/390, d1=-0.003, d2=-0.006, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 150
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 150
# 2/2 [==============================] - 0s 1ms/step
# >1, 151/390, d1=-0.003, d2=-0.006, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 151
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 151
# 2/2 [==============================] - 0s 1ms/step
# >1, 152/390, d1=-0.003, d2=-0.007, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 152
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 152
# 2/2 [==============================] - 0s 1ms/step
# >1, 153/390, d1=-0.003, d2=-0.007, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 153
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 153
# 2/2 [==============================] - 0s 1ms/step
# >1, 154/390, d1=-0.003, d2=-0.008, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 154
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 154
# 2/2 [==============================] - 0s 1ms/step
# >1, 155/390, d1=-0.004, d2=-0.009, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 155
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 155
# 2/2 [==============================] - 0s 1ms/step
# >1, 156/390, d1=-0.004, d2=-0.010, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 156
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 156
# 2/2 [==============================] - 0s 1ms/step
# >1, 157/390, d1=-0.005, d2=-0.011, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 157
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 157
# 2/2 [==============================] - 0s 1ms/step
# >1, 158/390, d1=-0.005, d2=-0.012, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 158
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 158
# 2/2 [==============================] - 0s 1ms/step
# >1, 159/390, d1=-0.005, d2=-0.013, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 159
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 159
# 2/2 [==============================] - 0s 2ms/step
# >1, 160/390, d1=-0.005, d2=-0.014, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 160
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 160
# 2/2 [==============================] - 0s 1ms/step
# >1, 161/390, d1=-0.006, d2=-0.015, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 161
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 161
# 2/2 [==============================] - 0s 1ms/step
# >1, 162/390, d1=-0.006, d2=-0.016, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 162
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 162
# 2/2 [==============================] - 0s 1ms/step
# >1, 163/390, d1=-0.007, d2=-0.018, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 163
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 163
# 2/2 [==============================] - 0s 1ms/step
# >1, 164/390, d1=-0.007, d2=-0.020, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 164
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 164
# 2/2 [==============================] - 0s 2ms/step
# >1, 165/390, d1=-0.008, d2=-0.021, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 165
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 165
# 2/2 [==============================] - 0s 1ms/step
# >1, 166/390, d1=-0.008, d2=-0.023, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 166
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 166
# 2/2 [==============================] - 0s 1ms/step
# >1, 167/390, d1=-0.009, d2=-0.025, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 167
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 167
# 2/2 [==============================] - 0s 1ms/step
# >1, 168/390, d1=-0.010, d2=-0.028, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 168
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 168
# 2/2 [==============================] - 0s 1ms/step
# >1, 169/390, d1=-0.010, d2=-0.030, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 169
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 169
# 2/2 [==============================] - 0s 1ms/step
# >1, 170/390, d1=-0.009, d2=-0.033, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 170
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 170
# 2/2 [==============================] - 0s 1ms/step
# >1, 171/390, d1=-0.012, d2=-0.036, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 171
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 171
# 2/2 [==============================] - 0s 2ms/step
# >1, 172/390, d1=-0.011, d2=-0.040, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 172
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 172
# 2/2 [==============================] - 0s 1ms/step
# >1, 173/390, d1=-0.013, d2=-0.043, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 173
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 173
# 2/2 [==============================] - 0s 1ms/step
# >1, 174/390, d1=-0.012, d2=-0.047, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 174
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 174
# 2/2 [==============================] - 0s 1ms/step
# >1, 175/390, d1=-0.014, d2=-0.052, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 175
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 175
# 2/2 [==============================] - 0s 1ms/step
# >1, 176/390, d1=-0.015, d2=-0.056, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 176
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 176
# 2/2 [==============================] - 0s 2ms/step
# >1, 177/390, d1=-0.016, d2=-0.062, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 177
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 177
# 2/2 [==============================] - 0s 1ms/step
# >1, 178/390, d1=-0.016, d2=-0.067, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 178
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 178
# 2/2 [==============================] - 0s 1ms/step
# >1, 179/390, d1=-0.020, d2=-0.074, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 179
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 179
# 2/2 [==============================] - 0s 1ms/step
# >1, 180/390, d1=-0.019, d2=-0.080, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 180
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 180
# 2/2 [==============================] - 0s 1ms/step
# >1, 181/390, d1=-0.019, d2=-0.087, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 181
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 181
# 2/2 [==============================] - 0s 1ms/step
# >1, 182/390, d1=-0.021, d2=-0.095, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 182
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 182
# 2/2 [==============================] - 0s 1ms/step
# >1, 183/390, d1=-0.020, d2=-0.104, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 183
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 183
# 2/2 [==============================] - 0s 1ms/step
# >1, 184/390, d1=-0.023, d2=-0.113, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 184
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 184
# 2/2 [==============================] - 0s 1ms/step
# >1, 185/390, d1=-0.025, d2=-0.123, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 185
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 185
# 2/2 [==============================] - 0s 1ms/step
# >1, 186/390, d1=-0.025, d2=-0.134, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 186
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 186
# 2/2 [==============================] - 0s 1ms/step
# >1, 187/390, d1=-0.023, d2=-0.145, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 187
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 187
# 2/2 [==============================] - 0s 1ms/step
# >1, 188/390, d1=-0.031, d2=-0.158, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 188
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 188
# 2/2 [==============================] - 0s 1ms/step
# >1, 189/390, d1=-0.028, d2=-0.171, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 189
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 189
# 2/2 [==============================] - 0s 1ms/step
# >1, 190/390, d1=-0.029, d2=-0.185, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 190
# Warning: Discriminator loss for real data out of bounds at epoch 1, batch 190
# 2/2 [==============================] - 0s 2ms/step
# >1, 191/390, d1=-0.036, d2=-0.202, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 1, batch 191
# ...
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 75
# 2/2 [==============================] - 0s 1ms/step
# >10, 76/390, d1=56.905, d2=-549.957, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 76
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 76
# 2/2 [==============================] - 0s 2ms/step
# >10, 77/390, d1=74.650, d2=-549.831, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 77
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 77
# 2/2 [==============================] - 0s 1ms/step
# >10, 78/390, d1=37.872, d2=-551.591, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 78
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 78
# 2/2 [==============================] - 0s 1ms/step
# >10, 79/390, d1=45.339, d2=-550.870, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 79
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 79
# 2/2 [==============================] - 0s 1ms/step
# >10, 80/390, d1=69.515, d2=-550.033, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 80
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 80
# 2/2 [==============================] - 0s 1ms/step
# >10, 81/390, d1=66.826, d2=-549.835, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 81
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 81
# 2/2 [==============================] - 0s 1ms/step
# >10, 82/390, d1=52.407, d2=-550.268, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 82
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 82
# 2/2 [==============================] - 0s 1ms/step
# >10, 83/390, d1=56.084, d2=-550.239, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 83
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 83
# 2/2 [==============================] - 0s 1ms/step
# >10, 84/390, d1=53.067, d2=-549.255, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 84
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 84
# 2/2 [==============================] - 0s 1ms/step
# >10, 85/390, d1=28.539, d2=-551.714, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 85
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 85
# 2/2 [==============================] - 0s 1ms/step
# >10, 86/390, d1=57.978, d2=-549.708, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 86
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 86
# 2/2 [==============================] - 0s 1ms/step
# >10, 87/390, d1=51.920, d2=-551.185, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 87
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 87
# 2/2 [==============================] - 0s 1ms/step
# >10, 88/390, d1=54.474, d2=-551.012, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 88
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 88
# 2/2 [==============================] - 0s 1ms/step
# >10, 89/390, d1=63.997, d2=-551.109, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 89
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 89
# 2/2 [==============================] - 0s 1ms/step
# >10, 90/390, d1=49.078, d2=-550.355, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 90
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 90
# 2/2 [==============================] - 0s 1ms/step
# >10, 91/390, d1=60.579, d2=-549.418, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 91
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 91
# 2/2 [==============================] - 0s 1ms/step
# >10, 92/390, d1=54.170, d2=-550.361, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 92
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 92
# 2/2 [==============================] - 0s 1ms/step
# >10, 93/390, d1=60.152, d2=-551.200, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 93
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 93
# 2/2 [==============================] - 0s 1ms/step
# >10, 94/390, d1=50.618, d2=-550.369, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 94
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 94
# 2/2 [==============================] - 0s 1ms/step
# >10, 95/390, d1=58.448, d2=-549.836, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 95
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 95
# 2/2 [==============================] - 0s 1ms/step
# >10, 96/390, d1=39.223, d2=-550.910, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 96
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 96
# 2/2 [==============================] - 0s 1ms/step
# >10, 97/390, d1=55.794, d2=-549.750, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 97
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 97
# 2/2 [==============================] - 0s 1ms/step
# >10, 98/390, d1=70.547, d2=-549.185, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 98
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 98
# 2/2 [==============================] - 0s 1ms/step
# >10, 99/390, d1=47.386, d2=-550.438, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 99
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 99
# 2/2 [==============================] - 0s 1ms/step
# >10, 100/390, d1=50.705, d2=-551.024, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 100
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 100
# 2/2 [==============================] - 0s 1ms/step
# >10, 101/390, d1=53.954, d2=-550.827, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 101
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 101
# 2/2 [==============================] - 0s 1ms/step
# >10, 102/390, d1=45.480, d2=-550.343, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 102
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 102
# 2/2 [==============================] - 0s 1ms/step
# >10, 103/390, d1=43.138, d2=-550.952, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 103
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 103
# 2/2 [==============================] - 0s 1ms/step
# >10, 104/390, d1=56.199, d2=-549.962, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 104
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 104
# 2/2 [==============================] - 0s 1ms/step
# >10, 105/390, d1=49.417, d2=-550.961, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 105
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 105
# 2/2 [==============================] - 0s 1ms/step
# >10, 106/390, d1=66.278, d2=-550.133, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 106
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 106
# 2/2 [==============================] - 0s 1ms/step
# >10, 107/390, d1=52.853, d2=-549.947, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 107
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 107
# 2/2 [==============================] - 0s 1ms/step
# >10, 108/390, d1=49.182, d2=-550.227, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 108
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 108
# 2/2 [==============================] - 0s 2ms/step
# >10, 109/390, d1=49.994, d2=-550.749, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 109
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 109
# 2/2 [==============================] - 0s 1ms/step
# >10, 110/390, d1=51.891, d2=-551.279, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 110
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 110
# 2/2 [==============================] - 0s 1ms/step
# >10, 111/390, d1=46.207, d2=-550.346, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 111
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 111
# 2/2 [==============================] - 0s 1ms/step
# >10, 112/390, d1=68.810, d2=-550.035, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 112
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 112
# 2/2 [==============================] - 0s 1ms/step
# >10, 113/390, d1=45.484, d2=-550.856, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 113
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 113
# 2/2 [==============================] - 0s 1ms/step
# >10, 114/390, d1=52.658, d2=-550.692, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 114
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 114
# 2/2 [==============================] - 0s 1ms/step
# >10, 115/390, d1=61.114, d2=-550.054, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 115
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 115
# 2/2 [==============================] - 0s 1ms/step
# >10, 116/390, d1=41.403, d2=-550.247, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 116
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 116
# 2/2 [==============================] - 0s 1ms/step
# >10, 117/390, d1=31.726, d2=-550.815, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 117
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 117
# 2/2 [==============================] - 0s 1ms/step
# >10, 118/390, d1=62.009, d2=-550.499, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 118
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 118
# 2/2 [==============================] - 0s 2ms/step
# >10, 119/390, d1=32.035, d2=-550.892, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 119
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 119
# 2/2 [==============================] - 0s 1ms/step
# >10, 120/390, d1=52.182, d2=-551.608, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 120
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 120
# 2/2 [==============================] - 0s 1ms/step
# >10, 121/390, d1=45.394, d2=-550.380, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 121
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 121
# 2/2 [==============================] - 0s 1ms/step
# >10, 122/390, d1=56.015, d2=-549.854, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 122
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 122
# 2/2 [==============================] - 0s 1ms/step
# >10, 123/390, d1=45.187, d2=-550.502, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 123
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 123
# 2/2 [==============================] - 0s 1ms/step
# >10, 124/390, d1=49.176, d2=-550.046, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 124
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 124
# 2/2 [==============================] - 0s 1ms/step
# >10, 125/390, d1=52.173, d2=-550.161, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 125
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 125
# 2/2 [==============================] - 0s 1ms/step
# >10, 126/390, d1=62.796, d2=-550.678, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 126
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 126
# 2/2 [==============================] - 0s 1ms/step
# >10, 127/390, d1=66.408, d2=-549.465, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 127
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 127
# 2/2 [==============================] - 0s 1ms/step
# >10, 128/390, d1=47.564, d2=-550.086, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 128
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 128
# 2/2 [==============================] - 0s 1ms/step
# >10, 129/390, d1=76.532, d2=-549.434, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 129
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 129
# 2/2 [==============================] - 0s 1ms/step
# >10, 130/390, d1=52.540, d2=-549.893, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 130
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 130
# 2/2 [==============================] - 0s 1ms/step
# >10, 131/390, d1=52.322, d2=-551.157, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 131
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 131
# 2/2 [==============================] - 0s 1ms/step
# >10, 132/390, d1=47.689, d2=-549.711, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 132
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 132
# 2/2 [==============================] - 0s 1ms/step
# >10, 133/390, d1=63.502, d2=-549.643, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 133
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 133
# 2/2 [==============================] - 0s 1ms/step
# >10, 134/390, d1=60.981, d2=-549.940, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 134
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 134
# 2/2 [==============================] - 0s 1ms/step
# >10, 135/390, d1=51.390, d2=-550.877, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 135
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 135
# 2/2 [==============================] - 0s 1ms/step
# >10, 136/390, d1=54.161, d2=-550.981, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 136
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 136
# 2/2 [==============================] - 0s 1ms/step
# >10, 137/390, d1=68.269, d2=-549.740, g=15.425
# Warning: Discriminator loss for fake data out of bounds at epoch 10, batch 137
# Warning: Discriminator loss for real data out of bounds at epoch 10, batch 137
# 1/2 [==============>...............] - ETA: 0s

# %%
from tensorflow.keras.models import load_model

# Load the generator model
generator = load_model('run-002/generator_model_200.h5')
latent_points = generate_latent_points(latent_dim, n_samples)  # latent_dim should match your model's expected input
# Generate images
generated_images = generator.predict(latent_points)
show_generated_images(generated_images)
